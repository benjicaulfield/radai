# %%
import re
import glob
import json
import string
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize

from wordcloud import WordCloud, ImageColorGenerator

# %%
'''create list of files with extension .json'''
jsons = glob.glob('jsons/*.json')

# %%
len(jsons)
# Out:
# 987

# %%
'''get list of text reports from all .json files'''
reports = []
for jsn in jsons:
    with open(jsn, 'r') as j:
        reports.append(json.loads(j.read()))

# %%
'''remove "ReportText" from beginning of each report in reports.
   put all text in lowercase.
   tokenize each word in each report
   remove stopwords from each report
   remove all words with numbers from list'''
stop_words = set(stopwords.words('english'))

clean_reports = [report['ReportText'].lower() for report in reports]
clean_reports = [word_tokenize(report) for report in clean_reports]
clean_reports = [[word for word in report if word not in stop_words] for report in clean_reports]
clean_reports = [[word for word in report if word.isalpha()] for report in clean_reports]

# %%
'''flatten list of lists into list of all unigrams'''
unigrams = sum(clean_reports, [])

# %%
'''create list of all bigrams from every report
   this expression can be adjusted and used for any size n-gram'''
bigrams = sum([[' '.join(report[i:i+2]) for i in range(len(report)-1)] for report in clean_reports], [])

# %%
'''how many total unigrams, how many unique unigrams'''
len(unigrams), len(set(unigrams))
# Out:
# (37829, 882)

# %%
'''how many total bigrams, how many unique bigrams'''
len(bigrams), len(set(bigrams))
# Out:
# (36842, 4186)

# %%
'''create dictionary of unigram and bigram counts'''
unigram_dict = dict(Counter(unigrams))
bigram_dict = dict(Counter(bigrams))

# %%
'''what bigrams have the highest probability with the lowest probability of the two words that comprise it?'''
bigram_probs = {}

for bigram in bigrams:
    first_word, last_word = bigram.split()
    bigram_probs[bigram] = bigram_dict[bigram] / (unigram_dict[first_word] + unigram_dict[last_word])
    
dict(sorted(bigram_probs.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'episode care': 0.5,
#  'shortness breath': 0.5,
#  'zip code': 0.5,
#  'habitus decreases': 0.5,
#  'decreases sensitivity': 0.5,
#  'sensitivity detect': 0.5,
#  'referral consultation': 0.5,
#  'consultation please': 0.5,
#  'please call': 0.5,
#  'medical imaging': 0.5,
#  'sent review': 0.5,
#  'oxygen tubing': 0.5,
#  'sex acct': 0.5,
#  'see discussion': 0.5,
#  'transcriptionist printed': 0.5,
#  'printed batch': 0.5,
#  'traverses esophagus': 0.5,
#  'esophagus ge': 0.5,
#  'positive ppd': 0.5,
#  'extrinsic compression': 0.5,
#  'generator sequential': 0.5,
#  'vena cava': 0.5,
#  'attending physician': 0.5,
#  'physician personally': 0.5,
#  'covid exposure': 0.5,
#  'technical factors': 0.5,
#  'opportunity provide': 0.5,
#  'including tracheostomy': 0.5,
#  'paratracheal stripe': 0.5,
#  'sore throat': 0.5,
#  'shallow inspiration': 0.5,
#  'feel like': 0.5,
#  'shoulder arthroplasty': 0.5,
#  'proper settings': 0.5,
#  'valve stenosis': 0.5,
#  'stenosis spec': 0.5,
#  'spec inst': 0.5,
#  'raise concern': 0.5,
#  'inferior margin': 0.5,
#  'non grid': 0.5,
#  'tof rpr': 0.5,
#  'labeled hrs': 0.5,
#  'innominate vein': 0.5,
#  'clavicular heads': 0.5,
#  'produced exertion': 0.5,
#  'exertion stress': 0.5,
#  'document lead': 0.5,
#  'sp oh': 0.5,
#  'cons olidations': 0.5,
#  'ventilation management': 0.5,
#  'insertion manipulation': 0.5,
#  'altered mental': 0.5,
#  'aggressive osseus': 0.5,
#  'middle third': 0.5,
#  'interventional procedures': 0.5,
#  'procedures signing': 0.5,
#  'volume loss': 0.5,
#  'text reason': 0.5,
#  'per requisition': 0.5,
#  'internal jugular': 0.4857142857142857,
#  'superior vena': 0.47058823529411764,
#  'cm carina': 0.4626865671641791,
#  'sulci sharp': 0.45454545454545453,
#  'films dictation': 0.45454545454545453,
#  'opacities evident': 0.4531024531024531,
#  'degree inflation': 0.4444444444444444,
#  'id hours': 0.43410852713178294,
#  'phones answered': 0.42857142857142855,
#  'interpreted supervised': 0.42857142857142855,
#  'electronically signed': 0.4264524103831891,
#  'pleural effusion': 0.42422145328719724,
#  'costophrenic sulci': 0.4166666666666667,
#  'trachea midline': 0.4117647058823529,
#  'signed personalname': 0.4085064292779426,
#  'mediastinal contours': 0.40192307692307694,
#  'adequately inflated': 0.4,
#  'thank referral': 0.4,
#  'extremity picc': 0.4,
#  'focal opacities': 0.39823008849557523,
#  'soft tissues': 0.3958333333333333,
#  'vascular congestion': 0.3923076923076923,
#  'detect pathology': 0.38461538461538464,
#  'resident agree': 0.38461538461538464,
#  'initial encounter': 0.38181818181818183,
#  'lower lobe': 0.37735849056603776,
#  'limitations cardiomediastinal': 0.375,
#  'diff breathing': 0.375,
#  'confines film': 0.375,
#  'standard positions': 0.375,
#  'expansion aeration': 0.3684210526315789,
#  'median sternotomy': 0.3684210526315789,
#  'cardiomediastinal contour': 0.3683360258481422,
#  'outlines normally': 0.36363636363636365,
#  'peribronchial cuffing': 0.35,
#  'visualized skeletal': 0.34328358208955223,
#  'courses diaphragm': 0.34285714285714286,
#  'body habitus': 0.3333333333333333,
#  'unknown origin': 0.3333333333333333,
#  'calcified granulomas': 0.3333333333333333,
#  'signer name': 0.3333333333333333,
#  'reactive airway': 0.3333333333333333,
#  'adm fax': 0.3333333333333333,
#  'requiring intubation': 0.3333333333333333,
#  'given projection': 0.3333333333333333,
#  'treatment unknown': 0.3333333333333333,
#  'unknown headache': 0.3333333333333333,
#  'arch calcifications': 0.3333333333333333,
#  'images interpreted': 0.3333333333333333,
#  'year old': 0.3333333333333333,
#  'former smoker': 0.3333333333333333,
#  'stat fax': 0.3333333333333333,
#  'like going': 0.3333333333333333,
#  'going pass': 0.3333333333333333,
#  'removed interim': 0.3333333333333333,
#  'inst cv': 0.3333333333333333,
#  'included least': 0.3333333333333333,
#  'near complete': 0.3333333333333333,
#  'allowing differences': 0.3333333333333333,
#  'signing radiologist': 0.3333333333333333,
#  'hemithorax probable': 0.3333333333333333,
#  'current smoker': 0.3333333333333333,
#  'compared prior': 0.3229166666666667,
#  'clinical history': 0.312451057165231,
#  'comparison none': 0.3122077922077922,
#  'pa lateral': 0.31125827814569534,
#  'respiratory failure': 0.30985915492957744,
#  'carina enteric': 0.3088235294117647,
#  'nontraumatic initial': 0.30434782608695654,
#  'effusion pneumothorax': 0.3024251069900143,
#  'lungs clear': 0.3021702838063439,
#  'monitor leads': 0.3,
#  'pt states': 0.3,
#  'located standard': 0.3,
#  'significant bone': 0.2893401015228426,
#  'knob atherosclerotic': 0.2857142857142857,
#  'sternal encircling': 0.2857142857142857,
#  'sternal cerclage': 0.2857142857142857,
#  'epicardial pacing': 0.2857142857142857,
#  'bottom film': 0.2857142857142857,
#  'personalname md': 0.278580814717477,
#  'dictated dictated': 0.2765151515151515,
#  'cardiopulmonary disease': 0.2748414376321353,
#  'leads overlie': 0.2727272727272727,
#  'tissues grossly': 0.2727272727272727,
#  'agree wording': 0.2727272727272727,
#  'old man': 0.2727272727272727,
#  'hardware located': 0.2727272727272727,
#  'adenopathy significant': 0.27230046948356806,
#  'endotracheal tube': 0.2717948717948718,
#  'central venous': 0.2708333333333333,
#  'final report': 0.2702702702702703,
#  'evident pleural': 0.2677595628415301,
#  'well expanded': 0.2647058823529412,
#  'approximately cm': 0.2631578947368421,
#  'status post': 0.2631578947368421,
#  'support devices': 0.26,
#  'displaced fracture': 0.25925925925925924,
#  'contours unremarkable': 0.259047619047619,
#  'skeletal structures': 0.25842696629213485,
#  'remain place': 0.25806451612903225,
#  'heart size': 0.25757575757575757,
#  'atelectasis either': 0.25735294117647056,
#  'soft tissue': 0.2564102564102564,
#  'similar compared': 0.25609756097560976,
#  'upper extremity': 0.2558139534883721,
#  'mediastinum within': 0.25331858407079644,
#  'nonacute foreign': 0.25,
#  'unexpected foreign': 0.25,
#  'given differences': 0.25,
#  'presented interpretation': 0.25,
#  'atherosclerotic calcification': 0.25,
#  'ge junction': 0.25,
#  'junction looped': 0.25,
#  'looped gastric': 0.25,
#  'gastric fundus': 0.25,
#  'representing combination': 0.25,
#  'likely artifactual': 0.25,
#  'subclavian generator': 0.25,
#  'examinations last': 0.25,
#  'air space': 0.25,
#  'thank opportunity': 0.25,
#  'pacemaker surgical': 0.25,
#  'pneumonitis discrete': 0.25,
#  'started morning': 0.25,
#  'states feel': 0.25,
#  'due overlying': 0.25,
#  'quadrant abdominal': 0.25,
#  'heads clavicular': 0.25,
#  'preoperative assessment': 0.25,
#  'states sick': 0.25,
#  'diffusely atherosclerotic': 0.25,
#  'atherosclerotic ectatic': 0.25,
#  'ectatic remainder': 0.25,
#  'clip epicardial': 0.25,
#  'subdiaphragmatic gastric': 0.25,
#  'gastric suction': 0.25,
#  'acute cardiopulmonary': 0.24703087885985747,
#  'lines tubes': 0.24242424242424243,
#  'thoracic spine': 0.24242424242424243,
#  'venous catheter': 0.24074074074074073,
#  'date pm': 0.23809523809523808,
#  'reviewed resident': 0.23809523809523808,
#  'diaphragm distal': 0.23529411764705882,
#  'aorta outlines': 0.23529411764705882,
#  'spine demonstrates': 0.23529411764705882,
#  'slightly improved': 0.23529411764705882,
#  'foreign body': 0.23076923076923078,
#  'frequently viral': 0.23076923076923078,
#  'performed portably': 0.22727272727272727,
#  'thorax exhibits': 0.22727272727272727,
#  'dictation reviewed': 0.22727272727272727,
#  'findings focal': 0.2228298017771702,
#  'call phone': 0.2222222222222222,
#  'uva radiology': 0.2222222222222222,
#  'radiology medical': 0.2222222222222222,
#  'medial bases': 0.2222222222222222,
#  'costophrenic angles': 0.2222222222222222,
#  'aerated consolidating': 0.2222222222222222,
#  'foundation radiology': 0.2222222222222222,
#  'radiology group': 0.2222222222222222,
#  'earlier today': 0.2222222222222222,
#  'cardiomediastinal silhouette': 0.21942446043165467,
#  'patient body': 0.21739130434782608,
#  'may represent': 0.21739130434782608,
#  'either lung': 0.2138728323699422,
#  'two views': 0.21348314606741572,
#  'pm clinical': 0.2131303520456708,
#  'slightly decreased': 0.21052631578947367,
#  'jugular catheter': 0.21052631578947367,
#  'workstation name': 0.21052631578947367,
#  'anatomy appears': 0.20930232558139536,
#  'volumes mediastinum': 0.20868113522537562,
#  'pneumothorax mediastinum': 0.20692567567567569,
#  'cr port': 0.20588235294117646,
#  'tubes lines': 0.20202020202020202,
#  'aortic knob': 0.2,
#  'tubing overlie': 0.2,
#  'proximal stomach': 0.2,
#  'complication remaining': 0.2,
#  'overlies gastric': 0.2,
#  'etiology reactive': 0.2,
#  'reactive airways': 0.2,
#  'sequential pacing': 0.2,
#  'years female': 0.2,
#  'relate combination': 0.2,
#  'last several': 0.2,
#  'attributable multifocal': 0.2,
#  'densely calcified': 0.2,
#  'calcified granuloma': 0.2,
#  'remains place': 0.2,
#  'scoliosis involving': 0.2,
#  'operative open': 0.2,
#  'level proximal': 0.2,
#  'known trauma': 0.2,
#  'positions described': 0.2,
#  'decompensation finalized': 0.2,
#  'portions radiopaque': 0.2,
#  'coronary artery': 0.2,
#  'thoracic aorta': 0.19444444444444445,
#  'radiography exam': 0.19236564540431944,
#  'well aerated': 0.19230769230769232,
#  'reviewed images': 0.19047619047619047,
#  'may reflect': 0.19047619047619047,
#  'exam date': 0.19000979431929482,
#  'initial episode': 0.1891891891891892,
#  'radiographic evidence': 0.1875,
#  'tract infection': 0.1875,
#  'bone abnormality': 0.18627450980392157,
#  'heart mediastinal': 0.18622448979591838,
#  'picc line': 0.18421052631578946,
#  'bibasilar airspace': 0.1827956989247312,
#  'portions remaining': 0.18181818181818182,
#  'remaining radiopaque': 0.18181818181818182,
#  'linear subsegmental': 0.18181818181818182,
#  'multilevel degenerative': 0.18181818181818182,
#  'degenerative joint': 0.18181818181818182,
#  'calcifications prominence': 0.18181818181818182,
#  'provide interpretation': 0.18181818181818182,
#  'bronchial cuffing': 0.18181818181818182,
#  'complete opacification': 0.18181818181818182,
#  'improvement hazy': 0.18181818181818182,
#  'interval change': 0.18032786885245902,
#  'enteric tube': 0.18023255813953487,
#  'bones soft': 0.1797752808988764,
#  'three days': 0.17777777777777778,
#  'phone phones': 0.17647058823529413,
#  'infection reactive': 0.17647058823529413,
#  'single view': 0.17525773195876287,
#  'aortic atherosclerosis': 0.17391304347826086,
#  'none impression': 0.17389033942558746,
#  'interstitial markings': 0.171875,
#  'pulmonary vascularity': 0.17114093959731544,
#  'technique view': 0.1690694626474443,
#  'suspicious unexpected': 0.16666666666666666,
#  'interval removal': 0.16666666666666666,
#  'position since': 0.16666666666666666,
#  'destructive lesion': 0.16666666666666666,
#  'regional skeleton': 0.16666666666666666,
#  'unspecified organism': 0.16666666666666666,
#  'female epigastric': 0.16666666666666666,
#  'density projected': 0.16666666666666666,
#  'pacing wires': 0.16666666666666666,
#  'tissue artifact': 0.16666666666666666,
#  'reported trauma': 0.16666666666666666,
#  'subsegmental areas': 0.16666666666666666,
#  'states worse': 0.16666666666666666,
#  'shaking today': 0.16666666666666666,
#  'concerning scarring': 0.16666666666666666,
#  'earlier day': 0.16666666666666666,
#  'extends inferior': 0.16666666666666666,
#  'sheath persists': 0.16666666666666666,
#  'degree distribution': 0.16666666666666666,
#  'prominent localized': 0.16666666666666666,
#  'read location': 0.16666666666666666,
#  'manipulation removal': 0.16666666666666666,
#  'aside chronic': 0.16666666666666666,
#  'developed interim': 0.16666666666666666,
#  'difficulty breathing': 0.16666666666666666,
#  'key portions': 0.16666666666666666,
#  'copd current': 0.16666666666666666,
#  'chronic bronchitic': 0.16666666666666666,
#  'cough fever': 0.166270783847981,
#  'pain comparison': 0.16545189504373178,
#  'tube tip': 0.1651376146788991,
#  'visible mass': 0.16470588235294117,
#  'chest radiography': 0.16218057921635434,
#  'structures unremarkable': 0.15980629539951574,
#  'osseous structures': 0.15878378378378377,
#  'infection asthma': 0.15789473684210525,
#  'aortic arch': 0.15789473684210525,
#  'personally reviewed': 0.15789473684210525,
#  'impression acute': 0.15429309231762428,
#  'diaphragm smooth': 0.15384615384615385,
#  'pacemaker leads': 0.15384615384615385,
#  'mid svc': 0.15384615384615385,
#  'years old': 0.15384615384615385,
#  'mildly prominent': 0.15384615384615385,
#  'patchy opacity': 0.15384615384615385,
#  'margin image': 0.15384615384615385,
#  'previous morning': 0.15384615384615385,
#  'segmental lobar': 0.15384615384615385,
#  'improved aeration': 0.15384615384615385,
#  'none technique': 0.15283018867924528,
#  'acute osseous': 0.15167785234899328,
#  'fracture patient': 0.15151515151515152,
#  'ap portable': 0.1511627906976744,
#  'confluent infiltrates': 0.1509433962264151,
#  'may due': 0.15,
#  'dictatedtime dictatedtime': 0.15,
#  'ij central': 0.14814814814814814,
#  'thoracic curvature': 0.14814814814814814,
#  'cardiopulmonary process': 0.14685314685314685,
#  'bone lesions': 0.14634146341463414,
#  'date clinical': 0.14585232452142205,
#  'bony thorax': 0.14563106796116504,
#  'active cardiopulmonary': 0.14540059347181009,
#  'xr chest': 0.1451388888888889,
#  'bony structures': 0.14418604651162792,
#  'pa lat': 0.14414414414414414,
#  'history cough': 0.14396887159533073,
#  'failure confluent': 0.14285714285714285,
#  'phone phone': 0.14285714285714285,
#  'address phys': 0.14285714285714285,
#  'age sex': 0.14285714285714285,
#  'persist retrocardiac': 0.14285714285714285,
#  'fluid mass': 0.14285714285714285,
#  'male age': 0.14285714285714285,
#  'hazy density': 0.14285714285714285,
#  'density medial': 0.14285714285714285,
#  'female chf': 0.14285714285714285,
#  'reflect viral': 0.14285714285714285,
#  'calcification wall': 0.14285714285714285,
#  'worsening last': 0.14285714285714285,
#  'could represent': 0.14285714285714285,
#  'asthma nonsmoker': 0.14285714285714285,
#  'op cabg': 0.14285714285714285,
#  'reflect combination': 0.14285714285714285,
#  'knee surgery': 0.14285714285714285,
#  'regions bilaterally': 0.14285714285714285,
#  'symmetrically aerated': 0.14285714285714285,
#  'vein sternal': 0.14285714285714285,
#  'abdominal drain': 0.14285714285714285,
#  'remaining aspects': 0.14285714285714285,
#  'mediastinum heart': 0.1424083769633508,
#  'impression normal': 0.14128521126760563,
#  'fracture visible': 0.140625,
#  'structures demonstrate': 0.14035087719298245,
#  'ribs demonstrate': 0.14,
#  'normal limits': 0.13984168865435356,
#  'degenerative changes': 0.13953488372093023,
#  'exam chest': 0.1389028686462003,
#  'contour normal': 0.13870967741935483,
#  'technique views': 0.1384909264565425,
#  'one week': 0.13846153846153847,
#  'chest pain': 0.13649122807017544,
#  'consolidation atelectasis': 0.13533834586466165,
#  'clinical data': 0.1337386018237082,
#  'basilar opacity': 0.13333333333333333,
#  'patient undergone': 0.13333333333333333,
#  'scarring chronic': 0.13333333333333333,
#  'cardiac silhouette': 0.13194444444444445,
#  'right ij': 0.13194444444444445,
#  'frontal lateral': 0.13108614232209737,
#  'view findings': 0.13097713097713098,
#  'visible bony': 0.13076923076923078,
#  'exam limitations': 0.13065902578796562,
#  'post open': 0.13043478260869565,
#  'report ends': 0.12903225806451613,
#  'osseous abnormality': 0.12871287128712872,
#  'clear visualized': 0.12861736334405144,
#  'lungs vessels': 0.12808988764044943,
#  'obtained id': 0.1259259259259259,
#  'size mediastinal': 0.1254416961130742,
#  'nodules pneumothoraces': 0.125,
#  'otherwise given': 0.125,
#  'leads oxygen': 0.125,
#  'address dob': 0.125,
#  'dob age': 0.125,
#  'radiology unit': 0.125,
#  'device placement': 0.125,
#  'reaching proximal': 0.125,
#  'ekg leads': 0.125,
#  'moderate hazy': 0.125,
#  'radiopaque foreign': 0.125,
#  'female preoperative': 0.125,
#  'surgical wires': 0.125,
#  'multifocal subsegmental': 0.125,
#  'pt presents': 0.125,
#  'pt shielded': 0.125,
#  'pt arrives': 0.125,
#  'worse breathing': 0.125,
#  'markings raise': 0.125,
#  'diffuse haziness': 0.125,
#  'drain epicardial': 0.125,
#  'otherwise relatively': 0.125,
#  'angles sharp': 0.125,
#  'encircling wires': 0.125,
#  'going past': 0.125,
#  'slightly diminished': 0.125,
#  'cerclage wires': 0.125,
#  'exam xr': 0.12448347107438017,
#  'lines appear': 0.12396694214876033,
#  'findings heart': 0.12395093608779859,
#  'parenchymal abnormalities': 0.12307692307692308,
#  'significant change': 0.12269938650306748,
#  'disease electronically': 0.12252252252252252,
#  'pulmonary vascular': 0.12251655629139073,
#  'none findings': 0.12173038229376258,
#  'within normal': 0.12136752136752137,
#  'three weeks': 0.12121212121212122,
#  'contours within': 0.12086330935251799,
#  'lat examination': 0.1206896551724138,
#  'osseous process': 0.12048192771084337,
#  'distal stomach': 0.12,
#  'mass adenopathy': 0.11904761904761904,
#  'ap pa': 0.1182170542635659,
#  'left basilar': 0.11764705882352941,
#  'wires clips': 0.11764705882352941,
#  'bases previous': 0.11764705882352941,
#  'ij catheter': 0.11666666666666667,
#  'vws dated': 0.11594202898550725,
#  'within exam': 0.11579481970543423,
#  'procedure cr': 0.11538461538461539,
#  'midline position': 0.11538461538461539,
#  'post median': 0.11538461538461539,
#  'appearance multifocal': 0.11538461538461539,
#  'appear intact': 0.11428571428571428,
#  'hila enlarged': 0.11428571428571428,
#  'basilar atelectasis': 0.11363636363636363,
#  'subclavian pacemaker': 0.1111111111111111,
#  'overlies mid': 0.1111111111111111,
#  'new patchy': 0.1111111111111111,
#  'undergone median': 0.1111111111111111,
#  'male stated': 0.1111111111111111,
#  'calcification involving': 0.1111111111111111,
#  'drain remains': 0.1111111111111111,
#  'distribution multifocal': 0.1111111111111111,
#  'leads projecting': 0.1111111111111111,
#  'old woman': 0.1111111111111111,
#  'undergone thoracentesis': 0.1111111111111111,
#  'thoracentesis postprocedure': 0.1111111111111111,
#  'widening atherosclerosis': 0.1111111111111111,
#  'previous day': 0.1111111111111111,
#  'clinical information': 0.109375,
#  'limits lungs': 0.10884353741496598,
#  'history shortness': 0.10850111856823266,
#  'cardiopulmonary abnormality': 0.10778443113772455,
#  'peribronchial thickening': 0.10714285714285714,
#  'encounter applicable': 0.10714285714285714,
#  'pleural effusions': 0.10638297872340426,
#  'atelectatic changes': 0.10526315789473684,
#  'may relate': 0.10526315789473684,
#  'cp nontraumatic': 0.10526315789473684,
#  'terminates region': 0.10526315789473684,
#  'ct removal': 0.10526315789473684,
#  'region junction': 0.10526315789473684,
#  'minimal increase': 0.10526315789473684,
#  'place orogastric': 0.10526315789473684,
#  'airspace disease': 0.10424710424710425,
#  'pulmonary vasculature': 0.10380622837370242,
#  'one month': 0.10344827586206896,
#  'region stomach': 0.10344827586206896,
#  'comparison xr': 0.10199714693295292,
#  'normal single': 0.10094637223974763,
#  'free infiltrate': 0.10071942446043165,
#  'distal tip': 0.1,
#  'right internal': 0.1,
#  'mildly tortuous': 0.1,
#  'arm picc': 0.1,
#  'enlargement thoracic': 0.1,
#  'past week': 0.1,
#  'projects superior': 0.1,
#  'wording report': 0.1,
#  'markings bilaterally': 0.1,
#  'degenerative spurring': 0.1,
#  'morning pt': 0.1,
#  'upper svc': 0.1,
#  'subtle increased': 0.1,
#  'wheezing eval': 0.1,
#  'previous study': 0.1,
#  'hx asthma': 0.1,
#  'wheezing bronchitis': 0.1,
#  'unremarkable none': 0.09771986970684039,
#  'support hardware': 0.0975609756097561,
#  'perihilar bibasilar': 0.09722222222222222,
#  'osseous abnormalities': 0.09722222222222222,
#  'information cough': 0.09718670076726342,
#  'similar appearance': 0.0967741935483871,
#  'interstitial edema': 0.09649122807017543,
#  'indication cough': 0.09619686800894854,
#  'tip approximately': 0.09615384615384616,
#  'radiopaque support': 0.09523809523809523,
#  'appropriate position': 0.09523809523809523,
#  'post op': 0.09523809523809523,
#  'satisfactory position': 0.09523809523809523,
#  'normally expanded': 0.09523809523809523,
#  'abnormality impression': 0.09519867549668874,
#  'views dated': 0.09496124031007752,
#  'catheter tip': 0.09401709401709402,
#  'hilar enlargement': 0.09302325581395349,
#  'edema infiltrates': 0.09278350515463918,
#  'views findings': 0.09273356401384084,
#  'tubes described': 0.09230769230769231,
#  'central peribronchial': 0.09090909090909091,
#  'pacing leads': 0.09090909090909091,
#  'viral etiology': 0.09090909090909091,
#  'dictation location': 0.09090909090909091,
#  'well positioned': 0.09090909090909091,
#  'supervised study': 0.09090909090909091,
#  'extends mid': 0.09090909090909091,
#  'mechanical ventilator': 0.09090909090909091,
#  'x today': 0.09090909090909091,
#  'mildly hyperinflated': 0.09090909090909091,
#  'persists bases': 0.09090909090909091,
#  'body aches': 0.09090909090909091,
#  'junction svc': 0.09090909090909091,
#  'compatible viral': 0.09090909090909091,
#  'setting viral': 0.09090909090909091,
#  'breathing x': 0.09090909090909091,
#  'repositioning described': 0.09090909090909091,
#  'previous episodes': 0.09090909090909091,
#  'previous mi': 0.09090909090909091,
#  'coarse alveolar': 0.09090909090909091,
#  'technique single': 0.09032258064516129,
#  'spaces appear': 0.0898876404494382,
#  'mild bibasilar': 0.0896551724137931,
#  'bony lesion': 0.0891089108910891,
#  'normal none': 0.08908685968819599,
#  'view chest': 0.0889487870619946,
#  'mass identified': 0.08888888888888889,
#  'trauma initial': 0.08823529411764706,
#  'intubation without': 0.08823529411764706,
#  'increased interstitial': 0.08823529411764706,
#  'history chest': 0.08749210360075806,
#  'data shortness': 0.08727272727272728,
#  'viral infection': 0.08695652173913043,
#  'minimal hazy': 0.08695652173913043,
#  'expansion patient': 0.08695652173913043,
#  'located region': 0.08695652173913043,
#  'normal volumes': 0.08620689655172414,
#  'interstitial prominence': 0.08620689655172414,
#  'region svc': 0.08571428571428572,
#  'fluid air': 0.0851063829787234,
#  'tube courses': 0.08496732026143791,
#  'ng tube': 0.08496732026143791,
#  'compared yesterday': 0.08450704225352113,
#  'bibasilar atelectasis': 0.08450704225352113,
#  'radiograph study': 0.08433734939759036,
#  'enlarged visualized': 0.08333333333333333,
#  'spine multilevel': 0.08333333333333333,
#  'terminates field': 0.08333333333333333,
#  'age age': 0.08333333333333333,
#  'relate viral': 0.08333333333333333,
#  'consistent viral': 0.08333333333333333,
#  'right basilar': 0.08333333333333333,
#  'scarring versus': 0.08333333333333333,
#  'width calcification': 0.08333333333333333,
#  'ij approach': 0.08333333333333333,
#  'today pt': 0.08333333333333333,
#  'lobe compressive': 0.08333333333333333,
#  'terminates midtrachea': 0.08333333333333333,
#  'none available': 0.08325266214908035,
#  'without evidence': 0.08163265306122448,
#  'submitted interpretation': 0.08163265306122448,
#  'fields demonstrate': 0.08163265306122448,
#  'size consolidation': 0.08149779735682819,
#  'abnormalities seen': 0.08148148148148149,
#  'pneumothorax pleural': 0.0814030443414957,
#  'hours endotracheal': 0.08108108108108109,
#  'lateral views': 0.08075601374570447,
#  'lung volumes': 0.08070175438596491,
#  'bilateral perihilar': 0.08045977011494253,
#  'prominence may': 0.08,
#  'significantly enlarged': 0.08,
#  'low lung': 0.08,
#  'clips diaphragm': 0.08,
#  'markings peribronchial': 0.08,
#  'region superior': 0.08,
#  'four weeks': 0.08,
#  'md dictated': 0.07966457023060797,
#  'breath comparison': 0.07962328767123288,
#  'left lower': 0.07947019867549669,
#  'diffuse interstitial': 0.07936507936507936,
#  'cough comparison': 0.07910906298003072,
#  'respiratory tract': 0.07894736842105263,
#  'respiratory distress': 0.07894736842105263,
#  'without ventilator': 0.07894736842105263,
#  'respiratory illness': 0.07894736842105263,
#  'diaphragm region': 0.07894736842105263,
#  'heart lungs': 0.0785876993166287,
#  'similar prior': 0.0784313725490196,
#  'jugular central': 0.0784313725490196,
#  'bibasilar subsegmental': 0.0784313725490196,
#  'structures appear': 0.07766990291262135,
#  'md electronically': 0.07692307692307693,
#  'parenchymal scarring': 0.07692307692307693,
#  'bases bilaterally': 0.07692307692307693,
#  'fundus distal': 0.07692307692307693,
#  'x days': 0.07692307692307693,
#  'sternotomy wires': 0.07692307692307693,
#  'changes persist': 0.07692307692307693,
#  'distress failure': 0.07692307692307693,
#  'failure requiring': 0.07692307692307693,
#  'gastric body': 0.07692307692307693,
#  'extends diaphragm': 0.07692307692307693,
#  'bases dictation': 0.07692307692307693,
#  'artifactual otherwise': 0.07692307692307693,
#  'old female': 0.07692307692307693,
#  'included image': 0.07692307692307693,
#  'ct thorax': 0.07692307692307693,
#  'sternotomy suture': 0.07692307692307693,
#  'oh surgery': 0.07692307692307693,
#  'years male': 0.07692307692307693,
#  'line placement': 0.07692307692307693,
#  'linear scarring': 0.07692307692307693,
#  'wheezing past': 0.07692307692307693,
#  'study obtained': 0.07608695652173914,
#  'effusion adenopathy': 0.07569721115537849,
#  'negative conclusion': 0.07563025210084033,
#  'central line': 0.07547169811320754,
#  'visualized ribs': 0.07526881720430108,
#  'pain technique': 0.07521697203471553,
#  'picc terminates': 0.075,
#  'lesion negative': 0.0743801652892562,
#  'change position': 0.07407407407407407,
#  'support lines': 0.07407407407407407,
#  'lobe suspicious': 0.07407407407407407,
#  'past weeks': 0.07407407407407407,
#  'single ap': 0.07386363636363637,
#  'pm technique': 0.07364685004436557,
#  'findings lungs': 0.07339449541284404,
#  'tip cm': 0.07339449541284404,
#  'unremarkable impression': 0.07330677290836653,
#  'viral lower': 0.07317073170731707,
#  'small airways': 0.07317073170731707,
#  'picc tip': 0.07291666666666667,
#  'available findings': 0.07237422771403354,
#  'seen image': 0.07216494845360824,
#  'ap view': 0.07206405693950178,
#  'impression negative': 0.07149489322191271,
#  'confluent infiltrate': 0.07142857142857142,
#  'abdominal anatomy': 0.07142857142857142,
#  'significant interval': 0.07142857142857142,
#  'bony anatomy': 0.07142857142857142,
#  'dictated personalname': 0.07142857142857142,
#  'hours shows': 0.07142857142857142,
#  'bases costophrenic': 0.07142857142857142,
#  'lesions conspicuous': 0.07142857142857142,
#  'cv surgery': 0.07142857142857142,
#  'x day': 0.07142857142857142,
#  'male intubation': 0.07142857142857142,
#  'patient reports': 0.07142857142857142,
#  'least stomach': 0.07142857142857142,
#  'infection contusion': 0.07142857142857142,
#  'throat three': 0.07142857142857142,
#  'aorta diffusely': 0.07142857142857142,
#  'age old': 0.07142857142857142,
#  'interval improvement': 0.07142857142857142,
#  'interval development': 0.07142857142857142,
#  'described worsening': 0.07142857142857142,
#  'diffuse bilateral': 0.07042253521126761,
#  'minimal bibasilar': 0.07017543859649122,
#  'visualized bony': 0.07017543859649122,
#  'changes thoracic': 0.07017543859649122,
#  'cst workstation': 0.06976744186046512,
#  'original report': 0.06896551724137931,
#  'report authenticated': 0.06896551724137931,
#  'well inflated': 0.06896551724137931,
#  'cuffing well': 0.06896551724137931,
#  'amount opacity': 0.06896551724137931,
#  'terminates mid': 0.06896551724137931,
#  'multifocal airspace': 0.06896551724137931,
#  'chest view': 0.06888289907157831,
#  'lung parenchyma': 0.0684931506849315,
#  'lung expansion': 0.0684931506849315,
#  'appear stable': 0.06808510638297872,
#  'thickening vasculature': 0.06779661016949153,
#  'single frontal': 0.06756756756756757,
#  'clear without': 0.06692913385826772,
#  'code phone': 0.06666666666666667,
#  'bony abnormalities': 0.06666666666666667,
#  'body suspicious': 0.06666666666666667,
#  'appearing definite': 0.06666666666666667,
#  'loc phone': 0.06666666666666667,
#  'thorax intact': 0.06666666666666667,
#  'free air': 0.06666666666666667,
#  'range minimal': 0.06666666666666667,
#  'atherosclerosis thoracic': 0.06666666666666667,
#  'tissue density': 0.06666666666666667,
#  'viral small': 0.06666666666666667,
#  'positioned diffuse': 0.06666666666666667,
#  'bilaterally new': 0.06666666666666667,
#  'tissue films': 0.06666666666666667,
#  'proximal thoracic': 0.06666666666666667,
#  'reports week': 0.06666666666666667,
#  'suture wires': 0.06666666666666667,
#  'heads ng': 0.06666666666666667,
#  'tortuous aorta': 0.06666666666666667,
#  'present key': 0.06666666666666667,
#  'wires gastrostomy': 0.06666666666666667,
#  'copd previous': 0.06666666666666667,
#  'markings coarse': 0.06666666666666667,
#  'stomach cardiothymic': 0.06666666666666667,
#  'effusions pneumothorax': 0.06588235294117648,
#  'lateral routine': 0.06565656565656566,
#  'catheter terminates': 0.06557377049180328,
#  'tube ng': 0.06535947712418301,
#  'sternotomy changes': 0.06521739130434782,
#  'bilateral interstitial': 0.06481481481481481,
#  'evidence acute': 0.06456241032998565,
#  'extensive bilateral': 0.06451612903225806,
#  'small left': 0.06451612903225806,
#  'interval decrease': 0.06451612903225806,
#  'mildly enlarged': 0.06451612903225806,
#  'appearance diffuse': 0.06451612903225806,
#  'ventilator support': 0.06382978723404255,
#  'tip region': 0.06382978723404255,
#  'since prior': 0.06349206349206349,
#  'yesterday study': 0.06349206349206349,
#  'pneumothorax normal': 0.0628992628992629,
#  'congestion fever': 0.06285714285714286,
#  'technique frontal': 0.06284153005464481,
#  'surgeries initial': 0.0625,
#  'vasculature cardiac': 0.0625,
#  'position soft': 0.0625,
#  'persistent bilateral': 0.0625,
#  'represent viral': 0.0625,
#  'address name': 0.0625,
#  'fax phone': 0.0625,
#  'transcribed transcriptionist': 0.0625,
#  'smooth bones': 0.0625,
#  'symptoms onset': 0.0625,
#  'terminates approximately': 0.0625,
#  'old male': 0.0625,
#  'normally inflated': 0.0625,
#  'tightness three': 0.0625,
#  'spaces show': 0.0625,
#  'indications preoperative': 0.0625,
#  'diminished perihilar': 0.0625,
#  'patient post': 0.0625,
#  'radiologist present': 0.0625,
#  'impression active': 0.06226053639846743,
#  'acute process': 0.06191117092866756,
#  'lobar consolidation': 0.06179775280898876,
#  'seen lines': 0.06153846153846154,
#  'data cough': 0.061124694376528114,
#  'pulmonary edema': 0.06109324758842444,
#  'workstation id': 0.06097560975609756,
#  'ett cm': 0.06060606060606061,
#  'upper abdomen': 0.06060606060606061,
#  'upper quadrant': 0.06060606060606061,
#  'cardiomediastinum appears': 0.06060606060606061,
#  'lower lobes': 0.06060606060606061,
#  'thoracic trachea': 0.06060606060606061,
#  'streaky perihilar': 0.06060606060606061,
#  'intact sternal': 0.06060606060606061,
#  'pa indication': 0.06030150753768844,
#  'unchanged endotracheal': 0.06,
#  'infiltrates evidence': 0.05921052631578947,
#  'radiology report': 0.058823529411764705,
#  'nontraumatic treatment': 0.058823529411764705,
#  'suspicious pneumonia': 0.058823529411764705,
#  'duration onset': 0.058823529411764705,
#  'thickening may': 0.058823529411764705,
#  'onset generalized': 0.058823529411764705,
#  'nonrheumatic aortic': 0.058823529411764705,
#  'aortic valve': 0.058823529411764705,
#  'cava hazy': 0.058823529411764705,
#  'epicardial wires': 0.058823529411764705,
#  'devices endotracheal': 0.058823529411764705,
#  'increase patchy': 0.058823529411764705,
#  'stress nontraumatic': 0.058823529411764705,
#  'caliber minimal': 0.058823529411764705,
#  'wires epicardial': 0.058823529411764705,
#  'mid trachea': 0.058823529411764705,
#  'months initial': 0.058823529411764705,
#  'right upper': 0.05844155844155844,
#  'appears negative': 0.058394160583941604,
#  'focal consolidation': 0.05802047781569966,
#  'view history': 0.057971014492753624,
#  'views clinical': 0.057672502574665295,
#  'structures unchanged': 0.05747126436781609,
#  'radiograph performed': 0.05747126436781609,
#  'infectious infiltrates': 0.05714285714285714,
#  'remain well': 0.05714285714285714,
#  'venous line': 0.05714285714285714,
#  'represent soft': 0.05714285714285714,
#  'base may': 0.05714285714285714,
#  'several days': 0.05714285714285714,
#  'dictated dt': 0.05714285714285714,
#  'five days': 0.05714285714285714,
#  'vw history': 0.05680317040951123,
#  'mild cardiomegaly': 0.05673758865248227,
#  'terminates cm': 0.05660377358490566,
#  'lines unchanged': 0.056179775280898875,
#  'subsegmental atelectasis': 0.056074766355140186,
#  'sign sign': 0.05555555555555555,
#  'visualized osseous': 0.05555555555555555,
#  'tube terminates': 0.05555555555555555,
#  'parabronchial thickening': 0.05555555555555555,
#  'patchy appearing': 0.05555555555555555,
#  'surgery x': 0.05555555555555555,
#  'infection unspecified': 0.05555555555555555,
#  'chf nontraumatic': 0.05555555555555555,
#  'patient years': 0.05555555555555555,
#  'wall aortic': 0.05555555555555555,
#  'rotated minimal': 0.05555555555555555,
#  'may voluntary': 0.05555555555555555,
#  'voluntary may': 0.05555555555555555,
#  'catheter remain': 0.05555555555555555,
#  'enlargement vascular': 0.05555555555555555,
#  'persists minimal': 0.05555555555555555,
#  'phone answered': 0.05555555555555555,
#  'slightly enlarged': 0.05555555555555555,
#  'bilateral airspace': 0.05555555555555555,
#  'postoperative changes': 0.05555555555555555,
#  'remain diminished': 0.05555555555555555,
#  'radiologist reviewed': 0.05555555555555555,
#  'week hx': 0.05555555555555555,
#  'abnormalities pleura': 0.0547945205479452,
#  'left lung': 0.0546875,
#  'identified radiographically': 0.05454545454545454,
#  'chronic interstitial': 0.05454545454545454,
#  'mild pulmonary': 0.054441260744985676,
#  'indication shortness': 0.054313099041533544,
#  'aeration infiltrate': 0.05426356589147287,
#  'small amount': 0.05405405405405406,
#  'four days': 0.05405405405405406,
#  'small layering': 0.05405405405405406,
#  'possible small': 0.05405405405405406,
#  'right atrium': 0.05384615384615385,
#  'fever three': 0.05357142857142857,
#  'perihilar opacity': 0.05357142857142857,
#  'pneumothorax acute': 0.053353658536585365,
#  'chest ap': 0.05290418054014059,
#  'sternal wires': 0.05263157894736842,
#  'resp failure': 0.05263157894736842,
#  'degrees upright': 0.05263157894736842,
#  'aortic calcifications': 0.05263157894736842,
#  'prominence lobar': 0.05263157894736842,
#  'fields otherwise': 0.05263157894736842,
#  'overall appearance': 0.05263157894736842,
#  'hyperinflation may': 0.05263157894736842,
#  'crowding small': 0.05263157894736842,
#  'illness nontraumatic': 0.05263157894736842,
#  'located cm': 0.05263157894736842,
#  'mid lower': 0.05263157894736842,
#  'increased prior': 0.05263157894736842,
#  'patient age': 0.05263157894736842,
#  'dt orogastric': 0.05263157894736842,
#  'bilateral pulmonary': 0.05245901639344262,
#  'thickening bones': 0.05194805194805195,
#  'answered id': 0.05194805194805195,
#  'lung base': 0.05194805194805195,
#  'two weeks': 0.05194805194805195,
#  'adenopathy bone': 0.05194805194805195,
#  'mediastinal silhouette': 0.05161290322580645,
#  'evidence failure': 0.05161290322580645,
#  'adenopathy hila': 0.05154639175257732,
#  'pm cdt': 0.05142857142857143,
#  'cdt electronically': 0.05128205128205128,
#  'past days': 0.05128205128205128,
#  'support apparatus': 0.05128205128205128,
#  'views indication': 0.051233396584440226,
#  'congestion bibasilar': 0.05084745762711865,
#  'procedure agree': 0.05084745762711865,
#  'lateral dated': 0.05067567567567568,
#  'support demonstrate': 0.05063291139240506,
#  'md pm': 0.05043227665706052,
#  'appear enlarged': 0.05,
#  'demonstrate acute': 0.05,
#  'status adm': 0.05,
#  'status hip': 0.05,
#  'involving aortic': 0.05,
#  'post operative': 0.05,
#  'jugular sheath': 0.05,
#  'tip terminates': 0.05,
#  'lead position': 0.05,
#  'mental status': 0.05,
#  'third svc': 0.05,
#  'sternotomy intact': 0.05,
#  'free text': 0.05,
#  'view comparison': 0.04997313272434175,
#  'portable examination': 0.04979253112033195,
#  'active disease': 0.04964539007092199,
#  'lesion seen': 0.04950495049504951,
#  'lung fields': 0.04895104895104895,
#  'infiltrate consolidation': 0.04878048780487805,
#  'patchy perihilar': 0.04878048780487805,
#  'prominence central': 0.04878048780487805,
#  'ij line': 0.04878048780487805,
#  'carina nasogastric': 0.04878048780487805,
#  'hilar contours': 0.04868913857677903,
#  'good lung': 0.04861111111111111,
#  'radiograph ct': 0.04838709677419355,
#  'prior studies': 0.04838709677419355,
#  'bones thoracic': 0.04819277108433735,
#  'basilar airspace': 0.04819277108433735,
#  'cough congestion': 0.047979797979797977,
#  'clear heart': 0.047879616963064295,
#  'et tube': 0.047619047619047616,
#  'aorta mildly': 0.047619047619047616,
#  'base linear': 0.047619047619047616,
#  'phone radiology': 0.047619047619047616,
#  'change moderate': 0.047619047619047616,
#  'post fall': 0.047619047619047616,
#  'grossly intact': 0.047619047619047616,
#  'onset pt': 0.047619047619047616,
#  'line projects': 0.047619047619047616,
#  'small moderate': 0.047619047619047616,
#  'cabg nontraumatic': 0.047619047619047616,
#  'increased crowding': 0.047619047619047616,
#  'apex may': 0.047619047619047616,
#  'jugular approach': 0.047619047619047616,
#  'aortic calcification': 0.047619047619047616,
#  'line advanced': 0.047619047619047616,
#  'line repositioning': 0.047619047619047616,
#  'line placed': 0.047619047619047616,
#  'tip located': 0.047058823529411764,
#  'silhouette within': 0.046875,
#  'skeletal lesion': 0.046875,
#  'pm cst': 0.04660194174757282,
#  'tube enteric': 0.046511627906976744,
#  'catheter thoracostomy': 0.046511627906976744,
#  'infiltrates previous': 0.046511627906976744,
#  'study slightly': 0.046511627906976744,
#  'left upper': 0.046357615894039736,
#  'right lung': 0.04633204633204633,
#  'pulmonary infiltrate': 0.04632152588555858,
#  'silhouette pulmonary': 0.046189376443418015,
#  'noted visualized': 0.046153846153846156,
#  'stable appearance': 0.045454545454545456,
#  'lower respiratory': 0.045454545454545456,
#  'configuration hila': 0.045454545454545456,
#  'leads remain': 0.045454545454545456,
#  'right lower': 0.045454545454545456,
#  'detected free': 0.045454545454545456,
#  'preoperative status': 0.045454545454545456,
#  'prior study': 0.045454545454545456,
#  'ij mediport': 0.045454545454545456,
#  'mildly low': 0.045454545454545456,
#  'interim catheter': 0.045454545454545456,
#  'described otherwise': 0.045454545454545456,
#  'review indication': 0.045112781954887216,
#  'bilateral lower': 0.0449438202247191,
#  'atelectasis infection': 0.044642857142857144,
#  'effusions seen': 0.04455445544554455,
#  'visualized portions': 0.044444444444444446,
#  'mild central': 0.044444444444444446,
#  'study transcribed': 0.044444444444444446,
#  'opacity increased': 0.044444444444444446,
#  'vessels normal': 0.04442825928623452,
#  'disease dictated': 0.04439746300211417,
#  'pleural fluid': 0.04428044280442804,
#  'acute abnormality': 0.044171779141104296,
#  'abnormalities vasculature': 0.04395604395604396,
#  'stomach tip': 0.04395604395604396,
#  'pulmonary vessels': 0.0438871473354232,
#  'personalname pm': 0.043731778425655975,
#  'technique pa': 0.04357298474945534,
#  ...}

# %%
most_common_words = FreqDist(unigrams).most_common(100)
wordcloud = WordCloud(width=1600, 
                      height=800, 
                      background_color='white').generate(str(most_common_words))

# %%
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 100 Most Common Words', fontsize=100)
plt.tight_layout(pad=0)
plt.show()

# %%
'''fields we are looking to parse'''
fields = ['exam', 'procedure', 'clinical', 'comparison', 'technique', 'findings', 'impression']

# %%
'''helper function to find index of first occurrence of field '''
def get_indices(report):
    indices = []
    for field in fields:
        try:
            indices.append(report.index(field))
        except ValueError:
            pass
    return sorted(indices)

# %%
field_dict = defaultdict(list)
sublists = []

for report in clean_reports:
    '''find index of first occurrence of each field in fields, sorted'''
    indices = get_indices(report)
    if len(indices) <= 1:
        field_dict['outliers'] = report
    else:
        '''break each report in to sublists split on field name'''
        for i in range(len(indices)-1):
            sublists.append(report[indices[i]:indices[i+1]])
        sublists.append(report[indices[-1]:])   

'''create dictionary with fields as keys, text as val'''
for sublist in sublists:
    field_dict[sublist[0]].append(sublist[1:])

# %%
'''create ANOTHER dictionary, with word counts for each field'''
fields_vocab = {}
for key in field_dict.keys():
    if key == 'outliers':
        fields_vocab[key] = dict(Counter(field_dict[key]))
    else:
        words = sum(field_dict[key], [])
        fields_vocab[key] = dict(Counter(words))

# %%
'''create dataframe from fields_vocab dict'''
field_df = pd.DataFrame.from_dict(fields_vocab)
field_df = field_df.fillna(0).astype('int32')
field_df['total'] = field_df.index.map(unigram_dict)

# %%
field_df
# Out:
#           outliers  exam  clinical  comparison  technique  findings  \
# chest            2  1002       237         317        228        88
# single           2    14         0           0         89        13
# view             2   224         2          42        375        23
# portable         2    27         0          62         37        29
# history          1   249       405          22          0         0
# ...            ...   ...       ...         ...        ...       ...
# organism         0     0         0           0          0         0
# wording          0     0         0           0          0         0
# former           0     0         0           0          0         0
# document         0     0         0           0          0         0
# lead             0     0         0           0          0         0
#
#           impression  procedure  total
# chest            421         49   2459
# single           160          4    284
# view             163         18    880
# portable          11          8    186
# history            4          5    707
# ...              ...        ...    ...
# organism           0          1      1
# wording            0          3      3
# former             0          1      1
# document           0          1      1
# lead               0          1      1
#
# [863 rows x 9 columns]

# %%
'''create dataframe of probabilities that a word is in that column'''
columns = [col for col in field_df.columns]
ratio_df = pd.DataFrame(columns=columns)
for column in columns:
    ratio_df[column] = field_df[column] / field_df['total']

# %%
ratio_df
# Out:
#           outliers      exam  clinical  comparison  technique  findings  \
# chest     0.000813  0.407483  0.096381    0.128914   0.092721  0.035787
# single    0.007042  0.049296  0.000000    0.000000   0.313380  0.045775
# view      0.002273  0.254545  0.002273    0.047727   0.426136  0.026136
# portable  0.010753  0.145161  0.000000    0.333333   0.198925  0.155914
# history   0.001414  0.352192  0.572843    0.031117   0.000000  0.000000
# ...            ...       ...       ...         ...        ...       ...
# organism  0.000000  0.000000  0.000000    0.000000   0.000000  0.000000
# wording   0.000000  0.000000  0.000000    0.000000   0.000000  0.000000
# former    0.000000  0.000000  0.000000    0.000000   0.000000  0.000000
# document  0.000000  0.000000  0.000000    0.000000   0.000000  0.000000
# lead      0.000000  0.000000  0.000000    0.000000   0.000000  0.000000
#
#           impression  procedure  total
# chest       0.171208   0.019927    1.0
# single      0.563380   0.014085    1.0
# view        0.185227   0.020455    1.0
# portable    0.059140   0.043011    1.0
# history     0.005658   0.007072    1.0
# ...              ...        ...    ...
# organism    0.000000   1.000000    1.0
# wording     0.000000   1.000000    1.0
# former      0.000000   1.000000    1.0
# document    0.000000   1.000000    1.0
# lead        0.000000   1.000000    1.0
#
# [863 rows x 9 columns]
